# %%
# @title 1. Налаштування (Запустити 1 раз)
import os
from google.colab import drive

# 1. Підключаємо диск
drive.mount('/content/drive')

# 2. Встановлюємо стабільний PyTorch (щоб GNN не компілювалася годину)
print("Setting up environment...")
# !pip uninstall torch torchvision torchaudio -y -q
# !pip install torch==2.4.0 torchvision==0.19.0 torchaudio==2.4.0 --index-url https://download.pytorch.org/whl/cu121 -q

# 3. Встановлюємо бібліотеки
# !pip install torch_geometric -q
# !pip install torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu121.html -q
# !pip install tqdm matplotlib pandas -q

print("✅ Environment ready!")

# %%
# @title 2. ЗАПУСК ТРЕНУВАННЯ
import os

# 1. Переходимо в папку проєкту (тут лежить твій main.py, train.py, models.py)
# Перевір, чи шлях правильний!
PROJECT_PATH = '/content/drive/MyDrive/Diplom/backend'
os.chdir(PROJECT_PATH)

print(f"Working directory: {os.getcwd()}")

# 2. Запускаємо скрипт train.py напряму!
# Всі зміни, які ти зробив у VS Code локально, тут вже враховані.

# Наприклад, тренуємо Advanced:
# !python train.py --model advanced --epochs 10 --batch-size 128 --limit 1000000 --device cuda

# Або розкоментуй це, щоб тренувати GNN:
# !python train.py --model gnn --epochs 10 --batch-size 64 --limit 100000 --device cuda
